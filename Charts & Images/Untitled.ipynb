# %% [markdown]
# ![budgetrevenue.png](attachment:budgetrevenue.png)

# %% [markdown]
# ![genreroi.png](attachment:genreroi.png)

# %% [markdown]
# ![monthrating.png](attachment:monthrating.png)

# %% [markdown]
# ![monthrevenue.png](attachment:monthrevenue.png)

# %% [markdown]
# ![releasedayrating.png](attachment:releasedayrating.png)

# %% [markdown]
# ![releasedayrevenue.png](attachment:releasedayrevenue.png)
